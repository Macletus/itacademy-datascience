# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
import requests

URL = "https://www.bolsasymercados.es/bme-exchange/es/Mercados-y-Cotizaciones/Acciones/Mercado-Continuo/Precios/ibex-35-ES0SI0000005"
page = requests.get(URL)
page_content = page.content

# %%
page_bs = BeautifulSoup(page_content, "html.parser")

# %%
page_bs.select("table-responsive")
# Out:
# []

# %%
print(page_bs)
# Out:
# <!DOCTYPE html>
#
# <html lang="es">
# ...
